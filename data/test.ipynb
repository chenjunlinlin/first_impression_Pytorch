# %%
import pandas as pd
import pickle

data_test = pd.read_pickle("annotation_test.pkl")
data_val = pd.read_pickle("annotation_validation.pkl")
data_train = pd.read_pickle("annotation_training.pkl")


# test_list = []
# keys = data_test.keys()
# for name in data_test['extraversion'].keys():
#     test_list.append([name, data_test['extraversion'][name], data_test['agreeableness'][name], data_test['conscientiousness'][name], data_test['neuroticism'][name], data_test['openness'][name]])
# test_df = pd.DataFrame(test_list)
index = ["VideoName", "ValueExtraversion", "ValueAgreeableness", "ValueConscientiousn", "ValueNeurotisicm", "ValueOpenness"]
# test_df.columns = index
# test_df.to_csv('test.csv', index=False)

# val_list = []
# keys = data_test.keys()
# for name in data_val['extraversion'].keys():
#     val_list.append([name, data_val['extraversion'][name], data_val['agreeableness'][name], data_val['conscientiousness'][name], data_val['neuroticism'][name], data_val['openness'][name]])
# val_df = pd.DataFrame(val_list)
# val_df.columns = index
# val_df.to_csv('val.csv', index=False)

data_val,
# Out:
# ({'extraversion': {'modNfUPt3F4.002.mp4': 0.6448598130841123,
#    'h6LOjpCRXtY.005.mp4': 0.4392523364485981,
#    'WER4ww680QQ.004.mp4': 0.4579439252336449,
#    'c4XnKouozXU.002.mp4': 0.36448598130841126,
#    'OEKg-Tvwcbk.002.mp4': 0.3457943925233645,
#    'PtA7yAu9-VE.003.mp4': 0.6448598130841123,
#    'TmpP2fXeVtk.004.mp4': 0.5514018691588786,
#    '1uC-2TZqplE.002.mp4': 0.48598130841121495,
#    '_01AyUz9J9I.003.mp4': 0.5794392523364487,
#    '_RfHkyf68Zs.000.mp4': 0.39252336448598135,
#    'n6JNJurop2U.005.mp4': 0.5981308411214954,
#    'dB65He57Ki8.003.mp4': 0.7009345794392524,
#    '7T-KyMnEbJM.000.mp4': 0.663551401869159,
#    'n0acEDmc0mA.001.mp4': 0.6822429906542057,
#    'IQdz0Pd-L2Y.000.mp4': 0.4018691588785047,
#    'OuE91U_n04E.005.mp4': 0.4953271028037384,
#    'NDC375coN1o.004.mp4': 0.35514018691588783,
#    '836kYlEs9GI.004.mp4': 0.3271028037383178,
#    '3yU-7AXnFCM.004.mp4': 0.18691588785046728,
#    'fBMKlYUjA9E.004.mp4': 0.6448598130841123,
# ...
